# %% [markdown]
# ### 저출산의 원인
# 저출산의 원인으로는 초혼연령이 점점 상승하는데 있다고 생각한다
# 그래서 최근 10년간 기혼자의 초혼연령을 분석해 추이를 확인해보려고 한다.

# %%
# 데이터 출처: KOSIS 국가통게포털 평균초혼연령 데이터

# %%
# 데이터 불러오기 
import pandas as pd
file_path = "C:/Users/admin/StudyAnaconda/team_project/김재홍 데이터/데이터프레임./평균초혼연령(10년간).csv"
df = pd.read_csv(file_path, header = 1)

# %%
df
# Out:
#        시군구별     남편     아내   남편.1   아내.1   남편.2   아내.2
# 0        전국  31.84  28.91  32.57  29.96  33.35  31.08
# 1     서울특별시  32.16  29.82  32.95  30.80  33.85  31.91
# 2     부산광역시  31.90  29.47  32.85  30.52  33.40  31.30
# 3     대구광역시  31.77  29.32  32.51  30.16  33.32  31.03
# 4     인천광역시  31.70  29.03  32.46  29.85  33.21  30.95
# 5     광주광역시  31.66  29.01  32.78  30.09  33.73  31.04
# 6     대전광역시  31.59  29.02  32.26  29.83  32.90  30.63
# 7     울산광역시  31.35  28.93  31.99  29.65  32.76  30.59
# 8   세종특별자치시      -      -  32.49  30.32  33.41  31.10
# 9       경기도  31.84  29.25  32.56  30.02  33.30  31.07
# 10      강원도  31.93  28.91  32.20  29.61  32.88  30.55
# 11     충청북도  31.50  28.50  32.15  29.48  32.74  30.36
# 12     충청남도  31.29  28.15  32.07  29.15  32.83  30.18
# 13     전라북도  31.77  28.48  32.58  29.40  33.35  30.62
# 14     전라남도  31.85  28.28  32.59  29.33  33.46  30.42
# 15     경상북도  31.46  28.58  32.33  29.53  33.23  30.68
# ...

# %%
# 결측치 대체(세종시)
df.fillna('')
# Out:
#        시군구별     남편     아내   남편.1   아내.1   남편.2   아내.2
# 0        전국  31.84  28.91  32.57  29.96  33.35  31.08
# 1     서울특별시  32.16  29.82  32.95  30.80  33.85  31.91
# 2     부산광역시  31.90  29.47  32.85  30.52  33.40  31.30
# 3     대구광역시  31.77  29.32  32.51  30.16  33.32  31.03
# 4     인천광역시  31.70  29.03  32.46  29.85  33.21  30.95
# 5     광주광역시  31.66  29.01  32.78  30.09  33.73  31.04
# 6     대전광역시  31.59  29.02  32.26  29.83  32.90  30.63
# 7     울산광역시  31.35  28.93  31.99  29.65  32.76  30.59
# 8   세종특별자치시      -      -  32.49  30.32  33.41  31.10
# 9       경기도  31.84  29.25  32.56  30.02  33.30  31.07
# 10      강원도  31.93  28.91  32.20  29.61  32.88  30.55
# 11     충청북도  31.50  28.50  32.15  29.48  32.74  30.36
# 12     충청남도  31.29  28.15  32.07  29.15  32.83  30.18
# 13     전라북도  31.77  28.48  32.58  29.40  33.35  30.62
# 14     전라남도  31.85  28.28  32.59  29.33  33.46  30.42
# 15     경상북도  31.46  28.58  32.33  29.53  33.23  30.68
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구별    19 non-null     object
#  1   남편      19 non-null     object
#  2   아내      19 non-null     object
#  3   남편.1    19 non-null     float64
#  4   아내.1    19 non-null     float64
#  5   남편.2    19 non-null     float64
#  6   아내.2    19 non-null     float64
# dtypes: float64(4), object(3)
# memory usage: 1.2+ KB

# %%
# 필요한 컬럼만 추출하기(2010년도)
df_2010 = df.loc[:,["시군구별","남편","아내"]]

# %%
df_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구별    19 non-null     object
#  1   남편      19 non-null     object
#  2   아내      19 non-null     object
# dtypes: object(3)
# memory usage: 584.0+ bytes

# %%
df_2010 = df_2010.drop(df.index[8]) # 세종시 행 제거(2010년엔 세종시가 없었음)

# %%
index_2010 = df_2010.set_index("시군구별") # 인덱스 시군구별로 바꾸기

# %%
index_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 전국 to 국외
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   남편      18 non-null     object
#  1   아내      18 non-null     object
# dtypes: object(2)
# memory usage: 432.0+ bytes

# %%
index2010 = index_2010.astype("float") # 인덱스 형 변환 float로

# %%
index_2010
# Out:
#             남편     아내
# 시군구별
# 전국       31.84  28.91
# 서울특별시    32.16  29.82
# 부산광역시    31.90  29.47
# 대구광역시    31.77  29.32
# 인천광역시    31.70  29.03
# 광주광역시    31.66  29.01
# 대전광역시    31.59  29.02
# 울산광역시    31.35  28.93
# 경기도      31.84  29.25
# 강원도      31.93  28.91
# 충청북도     31.50  28.50
# 충청남도     31.29  28.15
# 전라북도     31.77  28.48
# 전라남도     31.85  28.28
# 경상북도     31.46  28.58
# 경상남도     31.53  28.81
# 제주특별자치도  32.02  29.18
# 국외       32.99  25.36

# %%
marriage10 =index_2010.rename(index = {"제주특별자치도":"제주도"}) # 인덱스명 변경

# %%
marriage2010 = marriage10.astype("float") # 인덱스 형 변환

# %%
marriage2010.info() # 타입확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 전국 to 국외
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   남편      18 non-null     float64
#  1   아내      18 non-null     float64
# dtypes: float64(2)
# memory usage: 432.0+ bytes

# %%
# 2015년도
df_2015 = df.loc[:,["시군구별","남편.1","아내.1"]] # 필요한 열만 추출하기

# %%
df_2015.rename(columns = {'남편.1':'남편','아내.1':'아내'},inplace=True) # 컬럼명 변경하기

# %%
index_2015 = df_2015.set_index("시군구별") # 인덱스 시군구별로 바꾸기

# %%
marriage15 = index_2015.rename(index = ({"세종특별자치시":"세종시","제주특별자치도":"제주도"})) # 인덱스명 변경

# %%
marriage15.info() # 타입확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 전국 to 국외
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   남편      19 non-null     float64
#  1   아내      19 non-null     float64
# dtypes: float64(2)
# memory usage: 456.0+ bytes

# %%
# 2021년도
df_2021 = df.loc[:,["시군구별","남편.2","아내.2"]] # 필요한 열만 추출하기

# %%
df_2021.rename(columns = {'남편.2':'남편','아내.2':'아내'},inplace=True) # 컬럼명 바꾸기

# %%
index_2021 = df_2021.set_index("시군구별") # 인덱스 시군구별로 바꾸기

# %%
marriage21 = index_2021.rename(index = ({"세종특별자치시":"세종시","제주특별자치도":"제주도"})) # 인덱스명 변경

# %%
marriage21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 전국 to 국외
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   남편      19 non-null     float64
#  1   아내      19 non-null     float64
# dtypes: float64(2)
# memory usage: 456.0+ bytes

# %%
# 필요한 라이브러리 불러오기
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
# 한글깨짐 방지
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
plt.rc('figure', titlesize= 50)

ax1 = marriage2010.plot(kind='bar', title='2010년 지역별 초혼연령', figsize=(8, 8), legend=True, fontsize= 10) 
                                                                           # 그래프 종류와 제목,크기, 범례설정, 폰트크기
plt.xticks(rotation = 60) # x축 레이블명 회전
plt.ylim([20, 35])# Y축의 범위: [ymin, ymax]
ax1.set_xlabel('지역', fontsize = 12)    # x축 정보 표시
ax1.set_ylabel('나이', fontsize = 12)     # y축 정보 표시
plt.grid() # 그리드 라인 표시
plt.savefig('./2010년 초혼연령.png') # 이미지 저장하기
plt.show()

ax2 = marriage15.plot(kind='bar', title='2015년 지역별 초혼연령', figsize=(8, 8), legend=True, fontsize= 10) 
                                                                          # 그래프 종류와 제목, 크기, 범례설정, 폰트크기
plt.xticks(rotation = 60) # x축 레이블명 회전
plt.ylim([20, 35])     # Y축의 범위: [ymin, ymax] 
ax2.set_xlabel('지역', fontsize = 12)    # x축 정보 표시
ax2.set_ylabel('나이', fontsize = 12)     # y축 정보 표시
plt.grid() # 그리드 라인 표시
plt.savefig('./2015년 초혼연령.png') # 이미지 저장하기
plt.show()


ax3 = marriage21.plot(kind='bar', title='2021년 지역별 초혼연령', figsize=(8, 8), legend=True, fontsize= 10) 
                                                                         # 그래프 종류와 제목, 크기, 범례설정, 폰트크기
plt.xticks(rotation = 60) # x축 레이블명 회전
plt.ylim([20, 35])     # Y축의 범위: [ymin, ymax] 
ax3.set_xlabel('지역', fontsize = 12)    # x축 정보 표시
ax3.set_ylabel('나이', fontsize = 12)     # y축 정보 표시
plt.grid() # 그리드 라인 표시
plt.savefig('./2021년 초혼연령.png') # 이미지 저장하기
plt.show()
